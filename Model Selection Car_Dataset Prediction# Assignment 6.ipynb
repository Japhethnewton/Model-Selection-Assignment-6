# %% [markdown]
# # Description
#
# car price prediction in the automotive industry.Provide an overview of the dataset used for this assignment, including the relevant features and target variable.

# %% [markdown]
# # Aim of the project
#
# State the objective of the assignment, which is to predict car prices accurately using machine learning algorithms.

# %% [markdown]
#                                        #Task 1: Data Preprocessing:
# Steps involved in cleaning and preprocessing the dataset, such as handling missing values, categorical encoding, and feature scaling. (Dataset) Submission

# %% [markdown]
# Importing the Dependencies

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics

# %% [markdown]
# Data Collection and Processing

# %%
                            # loading the data from csv file to pandas dataframe
car = pd.read_csv("car data.csv")

# %%
                                    # inspecting the the dataframe
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
                               # Identifing the shape of the car Dataset
                                   # we have 300 rows and 9 columns

car.shape
# Out:
# (301, 9)

# %%
                                  # Expanding the rows and columns in the dataset

pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", None)

# %%
                         # Displaying the complete rows and columns for the car Dataset
car
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 0                         ritz  2014           3.35          5.590
# 1                          sx4  2013           4.75          9.540
# 2                         ciaz  2017           7.25          9.850
# 3                      wagon r  2011           2.85          4.150
# 4                        swift  2014           4.60          6.870
# 5                vitara brezza  2018           9.25          9.830
# 6                         ciaz  2015           6.75          8.120
# 7                      s cross  2015           6.50          8.610
# 8                         ciaz  2016           8.75          8.890
# 9                         ciaz  2015           7.45          8.920
# 10                    alto 800  2017           2.85          3.600
# 11                        ciaz  2015           6.85         10.380
# 12                        ciaz  2015           7.50          9.940
# ...

# %%
# Getting some information about the dataset

car.info()

# We have 4 objects , 3 int64 and 3floats
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
                                # Checking for the statistical  data for the car Dataset
car.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
car.max()
# Out:
# Car_Name              xcent
# Year                   2018
# Selling_Price          35.0
# Present_Price          92.6
# Kms_Driven           500000
# Fuel_Type            Petrol
# Seller_Type      Individual
# Transmission         Manual
# Owner                     3
# dtype: object

# %%
car.min()
# Out:
# Car_Name               800
# Year                  2003
# Selling_Price          0.1
# Present_Price         0.32
# Kms_Driven             500
# Fuel_Type              CNG
# Seller_Type         Dealer
# Transmission     Automatic
# Owner                    0
# dtype: object

# %%
car.std()
# Out:
# C:\Users\japheth.newton\AppData\Local\Temp\ipykernel_39264\2098329851.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   car.std()
# Year                 2.891554
# Selling_Price        5.082812
# Present_Price        8.644115
# Kms_Driven       38886.883882
# Owner                0.247915
# dtype: float64

# %%
car.count()
# Out:
# Car_Name         301
# Year             301
# Selling_Price    301
# Present_Price    301
# Kms_Driven       301
# Fuel_Type        301
# Seller_Type      301
# Transmission     301
# Owner            301
# dtype: int64

# %%
percentile_25= car.quantile(0.25)
percentile_50= car.quantile(0.50)
percentile_75 =car.quantile(0.75)

print(percentile_25)
print(percentile_50)
print(percentile_75)
# Out:
# Year              2012.0
# Selling_Price        0.9
# Present_Price        1.2
# Kms_Driven       15000.0
# Owner                0.0
# Name: 0.25, dtype: float64
# Year              2014.0
# Selling_Price        3.6
# Present_Price        6.4
# Kms_Driven       32000.0
# Owner                0.0
# Name: 0.5, dtype: float64
# Year              2016.0
# Selling_Price        6.0
# Present_Price        9.9
# Kms_Driven       48767.0
# Owner                0.0
# Name: 0.75, dtype: float64
# C:\Users\japheth.newton\AppData\Local\Temp\ipykernel_39264\434096486.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   percentile_25= car.quantile(0.25)
# ...

# %%
                          # Checking for number of object in the care data set and the counts

car.select_dtypes(include='object').value_counts()
# Out:
# Car_Name                   Fuel_Type  Seller_Type  Transmission
# city                       Petrol     Dealer       Manual          19
# corolla altis              Petrol     Dealer       Manual          11
# brio                       Petrol     Dealer       Manual           9
# fortuner                   Diesel     Dealer       Automatic        8
# Royal Enfield Classic 350  Petrol     Individual   Manual           7
# verna                      Petrol     Dealer       Manual           7
# amaze                      Petrol     Dealer       Manual           6
# eon                        Petrol     Dealer       Manual           6
# city                       Diesel     Dealer       Manual           6
# jazz                       Petrol     Dealer       Manual           6
# verna                      Diesel     Dealer       Manual           6
# alto k10                   Petrol     Dealer       Manual           5
# ...

# %%
                                   # checking the number of missing values
                                   # looks like we dont have any null values
car.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
# checking for the column names

car.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
# These rows have bike name and are not car names need  to drop them  and filter only the care names since its a car dataset
car['Car_Name'][100:201]
# Out:
# 100    Royal Enfield Thunder 500
# 101           UM Renegade Mojave
# 102                    KTM RC200
# 103            Bajaj Dominar 400
# 104    Royal Enfield Classic 350
# 105                    KTM RC390
# 106               Hyosung GT250R
# 107    Royal Enfield Thunder 350
# 108    Royal Enfield Thunder 350
# 109    Royal Enfield Classic 350
# 110                    KTM RC200
# 111    Royal Enfield Thunder 350
# 112                KTM 390 Duke
# 113          Mahindra Mojo XT300
# 114    Royal Enfield Classic 350
# 115    Royal Enfield Classic 350
# 116    Royal Enfield Classic 350
# 117    Royal Enfield Thunder 500
# 118    Royal Enfield Classic 350
# 119    Royal Enfield Thunder 500
# 120           Bajaj Pulsar RS200
# 121    Royal Enfield Thunder 350
# 122     Royal Enfield Bullet 350
# 123    Royal Enfield Classic 350
# 124    Royal Enfield Classic 500
# 125    Royal Enfield Classic 500
# 126            Bajaj Avenger 220
# 127            Bajaj Avenger 150
# ...

# %%
# dropping the rows that consist of bikes data 


# Identify the range of rows you want to remove
start_index = 100  # Starting row index
end_index = 201  # Ending row index

# Remove the rows from the DataFrame
car = car.drop(car.index[start_index:end_index])

# %%
car
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             ritz  2014           3.35           5.59       27000    Petrol
# 1              sx4  2013           4.75           9.54       43000    Diesel
# 2             ciaz  2017           7.25           9.85        6900    Petrol
# 3          wagon r  2011           2.85           4.15        5200    Petrol
# 4            swift  2014           4.60           6.87       42450    Diesel
# 5    vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             ciaz  2015           6.75           8.12       18796    Petrol
# 7          s cross  2015           6.50           8.61       33429    Diesel
# 8             ciaz  2016           8.75           8.89       20273    Diesel
# 9             ciaz  2015           7.45           8.92       42367    Diesel
# 10        alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
                           # Iterate over the columns and convert the first letter to uppercase
car['Car_Name'] = car['Car_Name'].str.capitalize()

# %%
car
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             Ritz  2014           3.35           5.59       27000    Petrol
# 1              Sx4  2013           4.75           9.54       43000    Diesel
# 2             Ciaz  2017           7.25           9.85        6900    Petrol
# 3          Wagon r  2011           2.85           4.15        5200    Petrol
# 4            Swift  2014           4.60           6.87       42450    Diesel
# 5    Vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             Ciaz  2015           6.75           8.12       18796    Petrol
# 7          S cross  2015           6.50           8.61       33429    Diesel
# 8             Ciaz  2016           8.75           8.89       20273    Diesel
# 9             Ciaz  2015           7.45           8.92       42367    Diesel
# 10        Alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
                           # Reset the index to the default numerical index
car.reset_index(drop=True, inplace=True)

# %%
car
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             Ritz  2014           3.35           5.59       27000    Petrol
# 1              Sx4  2013           4.75           9.54       43000    Diesel
# 2             Ciaz  2017           7.25           9.85        6900    Petrol
# 3          Wagon r  2011           2.85           4.15        5200    Petrol
# 4            Swift  2014           4.60           6.87       42450    Diesel
# 5    Vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             Ciaz  2015           6.75           8.12       18796    Petrol
# 7          S cross  2015           6.50           8.61       33429    Diesel
# 8             Ciaz  2016           8.75           8.89       20273    Diesel
# 9             Ciaz  2015           7.45           8.92       42367    Diesel
# 10        Alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
                                   # New shape of the car Dataset
car.shape
# Out:
# (200, 9)

# %%
car.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %% [markdown]
# # Task 2: Feature Selection and Engineering

# %%
#showing data correlation
car.corr
# Out:
# <bound method DataFrame.corr of           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0             Ritz  2014           3.35           5.59       27000    Petrol
# 1              Sx4  2013           4.75           9.54       43000    Diesel
# 2             Ciaz  2017           7.25           9.85        6900    Petrol
# 3          Wagon r  2011           2.85           4.15        5200    Petrol
# 4            Swift  2014           4.60           6.87       42450    Diesel
# 5    Vitara brezza  2018           9.25           9.83        2071    Diesel
# 6             Ciaz  2015           6.75           8.12       18796    Petrol
# 7          S cross  2015           6.50           8.61       33429    Diesel
# 8             Ciaz  2016           8.75           8.89       20273    Diesel
# 9             Ciaz  2015           7.45           8.92       42367    Diesel
# 10        Alto 800  2017           2.85           3.60        2135    Petrol
# ...

# %%
# draw Heat Map 

plt.figure(figsize=(15, 10))
sns.heatmap(car.corr(), annot=True)
plt.title('Heat Map', size=20)
plt.yticks(rotation = 0)
plt.show()
# Out:
# C:\Users\japheth.newton\AppData\Local\Temp\ipykernel_39264\871253331.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(car.corr(), annot=True)

# %% [markdown]
# PLot
#
# # Draw distribution diagram for Selling Price

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15, 10))
sns.distplot(car.Selling_Price)
plt.title('Car Price Distribution Plot')
plt.show()
# Out:
# C:\Users\japheth.newton\AppData\Local\Temp\ipykernel_39264\2425321202.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(car.Selling_Price)

# %%
                              # make function for count plot and scatter plots for Categorical features

def Categorical_Plot(column):
    
        plt.figure(figsize=(20, 5))
        plt.subplot(1,2,1)
        pd.value_counts(car[column]).plot(kind='bar')
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.ylabel("Count\n", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"{str(column)} - Count\n", fontsize = 15)

        plt.subplot(1, 2,2)
        plt.scatter(car[column], car.Selling_Price)
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"{str(column)} - Selling_Price\n", fontsize = 15)
        plt.ylabel("Selling_Price\n", fontsize=15)

        plt.show()

# %%
# call Categorical_Plot fuction for Fuel_Type

Categorical_Plot("Fuel_Type")

# %%
Categorical_Plot("Seller_Type")

# %%
Categorical_Plot("Transmission")

# %%
Categorical_Plot("Owner")

# %%
                      # make function for box plots for outliers and scatter plots for Numerical features

# %%
def Numerical_Plot(column):
    
        plt.figure(figsize=(20, 5))
        plt.subplot(1,2,1)
        sns.boxplot(car[column])
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"\n{str(column)} Box Plot\n", fontsize = 15)

        plt.subplot(1, 2,2)
        plt.scatter(car[column], car.Selling_Price)
        plt.xticks( horizontalalignment="center", fontsize=15)
        plt.xlabel(f"\n{str(column)}", fontsize=15)
        plt.yticks(fontsize = 15)
        plt.title(f"{str(column)} - Selling_Price\n", fontsize = 15)
        plt.ylabel("Selling_Price\n", fontsize=15)

        plt.show()

# %%
# call Numerical_Plot fuction for Age

Numerical_Plot("Present_Price")

# %%
Numerical_Plot("Kms_Driven")

# %%
plt.figure(figsize=(25, 5))
sns.pairplot(car)
plt.show()

# %%
                         # checking the distribution of categorical data 
car.Fuel_Type.value_counts()
car.Seller_Type.value_counts()
car.Transmission.value_counts()
# Out:
# Manual       169
# Automatic     31
# Name: Transmission, dtype: int64

# %%
print(car.Fuel_Type.value_counts())
print(car.Seller_Type.value_counts())
print(car.Transmission.value_counts())
# Out:
# Petrol    138
# Diesel     60
# CNG         2
# Name: Fuel_Type, dtype: int64
# Dealer        195
# Individual      5
# Name: Seller_Type, dtype: int64
# Manual       169
# Automatic     31
# Name: Transmission, dtype: int64

# %%
# Endconing categorical features to numerical

# %%
# encoding "Fuel_Type" column
car.replace({'Fuel_Type':{'Petrol':0, 'Diesel':1, 'CNG':2}},inplace=True)

# encoding "Seller_Type" column
car.replace({'Seller_Type':{'Dealer':0, 'Individual':1}},inplace=True)

# encoding "Transmission" column
car.replace({'Transmission':{'Manual':0, 'Automatic':1}},inplace=True)

# %%
# Check to see if it has been encoded the car Dataset
car.head(200)
# Out:
#           Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0             Ritz  2014           3.35           5.59       27000          0
# 1              Sx4  2013           4.75           9.54       43000          1
# 2             Ciaz  2017           7.25           9.85        6900          0
# 3          Wagon r  2011           2.85           4.15        5200          0
# 4            Swift  2014           4.60           6.87       42450          1
# 5    Vitara brezza  2018           9.25           9.83        2071          1
# 6             Ciaz  2015           6.75           8.12       18796          0
# 7          S cross  2015           6.50           8.61       33429          1
# 8             Ciaz  2016           8.75           8.89       20273          1
# 9             Ciaz  2015           7.45           8.92       42367          1
# 10        Alto 800  2017           2.85           3.60        2135          0
# ...

# %% [markdown]
# :

# %% [markdown]
# # Feature selection Example L1 regularization(Lasso) with car data set

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import train_test_split


# Separate the features and target variable
X = car.drop(['Car_Name', 'Selling_Price'], axis=1)
Y = car['Selling_Price']

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create a Lasso regression model
lasso = Lasso(alpha=0.1)

# Fit the model on the training data
lasso.fit(X_train, Y_train)

# Get the coefficients and corresponding feature names
coefficients = lasso.coef_
feature_names = X.columns

# Print the feature names along with their coefficients
for feature, coef in zip(feature_names, coefficients):
    print(f"{feature}: {coef}")
# Out:
# Year: 0.47168219858464955
# Present_Price: 0.4577136665609544
# Kms_Driven: -2.8598818849527785e-05
# Fuel_Type: 1.208088950892691
# Seller_Type: 0.0
# Transmission: 0.8349749581978533
# Owner: -0.0

# %% [markdown]
# feature names along with their corresponding coefficients. This allows us to understand the importance of each feature predicting the selling price of cars in the dataset.

# %% [markdown]
# # Feature Engineering Example using Interaction Feature on car Datset

# %%
car.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Kms_Driven',
#        'Fuel_Type', 'Seller_Type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression


# Create an interaction feature
car['interaction'] = car['Present_Price'] * car['Kms_Driven']

# Separate the features and target variable
X = car[['Present_Price', 'Kms_Driven', 'interaction']]
Y = car['Selling_Price']

# Train a model using the interaction feature
model = LinearRegression()
model.fit(X, Y)

# Print the coefficients
print("Coefficient for Present_Price:", model.coef_[0])
print("Coefficient for Kms_Driven:", model.coef_[1])
print("Coefficient for interaction:", model.coef_[2])
# Out:
# Coefficient for Present_Price: 0.8329000636570133
# Coefficient for Kms_Driven: 2.7308545688843023e-06
# Coefficient for interaction: -5.027890399410865e-06

# %% [markdown]
# The coefficients of the model are printed. The coefficients represent the impact of each feature (Present_Price, Kms_Driven, and the interaction feature) on the target variable (Selling_Price).

# %% [markdown]
# # Task 3: Algorithms:Introduce at least two machine learning algorithms used for car price prediction These techniques will help to improve our Model

# %% [markdown]
# 1. Gradient Boosting is a popular machine learning technique that combines multiple weak predictive models (typically decision trees) to create a strong predictive model.
#
#     How can it help our car data set: Gradient Boosting can be beneficial for your car dataset model like ,Predictive Power,Handling Different Types of Features, Regularization and Robustness to Outliers.
#
#     We going to use Gradient Boosting  in our Car Data set
#
#     Gradient Boosting algorithms have several hyperparameters that control the behavior and performance of the models like Number of Estimators (n_estimators), Tree-Specific Hyperparameters , Regularization Hyperparameter etc.

# %% [markdown]
# 2.  Random Forest is a popular ensemble learning method used for both classification and regression tasks. It combines the    predictions of multiple decision trees to make more accurate predictions. Each decision tree is built on a randomly sampled subset of the training data
#
#     How can it help our car data set:Random Forest is beneficial for car data like Handling Nonlinearity,Robustness to Outliers,Robustness to Overfitting, Predictive Performance However, it's important to note that the effectiveness of Random Forest (or any machine learning algorithm) depends on the quality of the data
#
#     We going  to use Random Forest in our Car Data set
#
#     Random Forest is an ensemble learning method hyperparameters in Random Forest we can use Number of Estimators The n_estimators ,Tree Depth The max_depth and Number of Features: The max_features etc.

# %% [markdown]
# # Task 4: Training, Evaluation & Selection

# %%
              #   Task 1 performing Gradient Boosting regression for car prediction using a dataset
    
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


# Split the dataset into features (X) and target variable (Y)
X = car.drop(['Car_Name', 'Selling_Price'], axis=1)
Y = car['Selling_Price']

# Split the dataset into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create and fit the Gradient Boosting model
GBmodel = GradientBoostingRegressor()
GBmodel.fit(X_train, Y_train)

# Make predictions on the train set
Y_pred = GBmodel.predict(X_train)

# Calculate the Mean  Errors
mse = mean_squared_error(Y_train, Y_pred)
print("Mean Squared Error:", mse)
error_score = metrics.r2_score(Y_train, Y_pred)
print("R squared Error : ", error_score)
mae = mean_absolute_error(Y_train, Y_pred)
print("Mean Absolute Error:", mae)
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.0979710966743671
# R squared Error :  0.996360554464599
# Mean Absolute Error: 0.252977002868746
# Root Mean Squared Error: 0.3130033493021554

# %%
# Prediction of the train Data
plt.scatter(Y_train, Y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# Make predictions on the test set
Y_pred = model.predict(X_test)

# Calculate the Mean Errors
mse = mean_squared_error(Y_test, Y_pred)
print("Mean Squared Error:", mse)
error_score = metrics.r2_score(Y_test, Y_pred)
print("R squared Error : ", error_score)
mae = mean_absolute_error(Y_test, Y_pred)
print("Mean Absolute Error:", mae)
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 1.0982095344439968
# R squared Error :  0.9547515325943942
# Mean Absolute Error: 0.7704351866374326
# Root Mean Squared Error: 1.04795492958619

# %%
# Prediction of the test Data
plt.scatter(Y_test, Y_pred)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
                          #Task 2 performing Random Forest regression for car prediction using a dataset
    
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error


# Separate the features and target variable
x = car.drop(['Car_Name', 'Selling_Price'], axis=1)
y = car["Selling_Price"]

# Split the dataset into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# Create and train the Random Forest Regression model
RFmodel = RandomForestRegressor()
RFmodel.fit(x_train, y_train)

# Make predictions on the train set
y_pred = RFmodel.predict(x_train)

# Calculate the Mean  Error
mse = mean_squared_error(y_train, y_pred)
print("Mean Squared Error:", mse)
error_score = metrics.r2_score(y_train, y_pred)
print("R squared Error : ", error_score)
mae = mean_absolute_error(y_train, y_pred)
print("Mean Absolute Error:", mae)
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.5979583414374998
# R squared Error :  0.9777869505397725
# Mean Absolute Error: 0.37895062499999976
# Root Mean Squared Error: 0.7732776612818321

# %%
# Prediction of the train Data
sns.scatterplot(y_train)
sns.scatterplot(y_pred)
plt.xticks(rotation=90)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)

# Calculate the Mean  Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
error_score = metrics.r2_score(y_test, y_pred)
print("R squared Error : ", error_score)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
rmse = np.sqrt(mse)
print("Root Mean Squared Error:", rmse)
# Out:
# Mean Squared Error: 0.9985044207499996
# R squared Error :  0.9588595861539904
# Mean Absolute Error: 0.7155524999999999
# Root Mean Squared Error: 0.9992519305710645

# %%
# Prediction of the test Data
sns.scatterplot(y_test)
sns.scatterplot(y_pred)
plt.xticks(rotation=90)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title(" Actual Prices vs Predicted Prices")
plt.show()

# %% [markdown]
# # Conclusion
#
# Based on the evaluation metrics you obtained for both models, specifically the Mean Squared Error (MSE), R-squared Error (R2), Mean Absolute Error (MAE), and Root Mean Squared Error (RMSE), you concluded that the Random Forest Regression model performed better for predicting car prices in the training and testing of the dataset.
#
# The lower the values of MSE and MAE, the better the model's performance in terms of minimizing prediction errors. Additionally, a higher R-squared value indicates a better fit of the model to the data.
#
# Since we mentioned that the Random Forest Regression model had better scores in these metrics, it suggests that the Random Forest model outperformed the Gradient Boosting model in predicting car prices for the specific dataset.
